# %% [markdown]
# # DeVISE
# Paper: [Frome et al. 2013](https://static.googleusercontent.com/media/research.google.com/en//pubs/archive/41473.pdf)

# %%
# %matplotlib inline

# %%
from fastai.conv_learner import *
import fastText as ft
import torchvision.transforms as transforms
from fastai.io import get_data

# %%
torch.backends.cudnn.benchmark=True

# %% [markdown]
# ## Data
# ### Imagenet data

# %%
PATH = Path('data/imagenet')
TMP_PATH = PATH/'tmp'
TRANS_PATH = Path('data/translate/word_vectors')
PATH_TRAIN = PATH/'train'

# %%
sz = 224

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # values for imagenet

tfms = transforms.Compose([
    transforms.RandomSizedCrop(sz),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    normalize
])

# %%
arch = resnet50

# %%
ttfms, vtfms = tfms_from_model(arch, sz, transforms_side_on, max_zoom=1.1)

# %% [markdown]
# ### Wordvectors

# %%
wordvectors = ft.load_model(str((TRANS_PATH/'wiki.en.bin')))

# %%
wordvectors.get_word_vector("house").shape
# Out:
# (300,)

# %% [markdown]
# #### Correlation

# %%
np.corrcoef(wordvectors.get_word_vector("house"), wordvectors.get_word_vector("building"))
# Out:
# array([[1.     , 0.46162],
#        [0.46162, 1.     ]])

# %%
np.corrcoef(wordvectors.get_word_vector("house"), wordvectors.get_word_vector("ant"))
# Out:
# array([[1.     , 0.05766],
#        [0.05766, 1.     ]])

# %% [markdown]
# **The word vectors of things that are similar are correlated (house, building) and those of words that are not similar are not correlated (house, ant).**

# %% [markdown]
# ### Map imagenet classes to word vectors

# %%
words = wordvectors.get_words(include_freq=True)

# %%
word_dict = {k:v for k,v in zip(*words)}

# %%
words = sorted(word_dict.keys(), key=lambda x: word_dict[x])

# %%
len(words)
# Out:
# 2519370

# %% [markdown]
# **List of the names of the 1000 imagenet classes:**

# %%
CLASSES_FN = 'imagenet_class_index.json'

# %%
get_data(f'http://files.fast.ai/models/{CLASSES_FN}', TMP_PATH/CLASSES_FN)

# %%
class_dict = json.load((TMP_PATH/CLASSES_FN).open())

# %%
classIds_imagenet = dict(class_dict.values())

# %%
class_dict["1"]
# Out:
# ['n01443537', 'goldfish']

# %% [markdown]
# **List of 'all' english nouns according to WortNet:**

# %%
WORDS_FN = 'classids.txt'
get_data(f'http://files.fast.ai/data/{WORDS_FN}', PATH/WORDS_FN)

# %%
classid_nouns = (PATH/WORDS_FN).open().readlines()

# %%
classid_nouns[:3]  # Look at the format. Imagenet uses WordNet classes :)
# Out:
# ['n00001740 entity\n',
#  'n00001930 physical_entity\n',
#  'n00002137 abstraction\n']

# %%
classIds_wordnet = dict(l.strip().split() for l in classid_nouns)

# %%
len(classIds_wordnet)  # english nouns
# Out:
# 82115

# %%
len(classIds_imagenet)  # imagenet classes
# Out:
# 1000

# %% [markdown]
# **Next, take the ~80k nouns in WordNet and look them up in the FastText word vectors:**

# %%
wordvector_dict = {w.lower() : wordvectors.get_word_vector(w) for w in words[-1000000:]}  # maps word to its vec

# %%
wordvector_dict["cat"].shape
# Out:
# (300,)

# %%
wordnet_id2wordvec = [(key, wordvector_dict[val.lower()]) for key, val in classIds_wordnet.items() if val.lower() in wordvector_dict]

# %% [markdown]
# **Makes a tuple of WordNet-id and respective wordvector for all classes in WordNet if the wordvector exists in FastText.**

# %%
len(wordnet_id2wordvec)
# Out:
# 49469

# %% [markdown]
# **We found the wordvectors for ~49k words in WordNet**
#
# **Now we do the same for the 1000 imagenet classes: tuple of id and wordvector**

# %%
imagenet_id2wordvec = [(key, wordvector_dict[val.lower()]) for key, val in classIds_imagenet.items() if val.lower() in wordvector_dict]

# %%
len(imagenet_id2wordvec)
# Out:
# 574

# %%
pickle.dump(wordnet_id2wordvec, (TMP_PATH/'wordnet_id2wordvec.pkl').open('wb'))
pickle.dump(imagenet_id2wordvec, (TMP_PATH/'imagenet_id2wordvec.pkl').open('wb'))

# %%
wordnet_id2wordvecv = pickle.load((TMP_PATH/'wordnet_id2wordvec.pkl').open('rb'))
imagenet_id2wordvec = pickle.load((TMP_PATH/'imagenet_id2wordvec.pkl').open('rb'))

# %%
wordnet_id2wordvec_dict = dict(wordnet_id2wordvec)

# %% [markdown]
# **Now we need to create the training dataset: The inputs are the images from imagenet, the labels are the wordvectors from FastText**

# %%
input_images = []
label_wordvecs = []

# %%
for d in (PATH/'train').iterdir():
    if d.name not in wordnet_id2wordvec_dict: continue
    vec = wordnet_id2wordvec_dict[d.name]
    for f in d.iterdir():
        input_images.append(str(f.relative_to(PATH)))
        label_wordvecs.append(vec)

# %%
len(input_images), len(label_wordvecs)
# Out:
# (14048, 14048)

# %%
label_wordvecs = np.stack(label_wordvecs)

# %%
label_wordvecs.shape
# Out:
# (14048, 300)

# %%
arch = resnet34

# %%
val_indcs = get_cv_idxs(len(input_images), val_pct=0.1)

# %%
tfms = tfms_from_model(arch, sz, transforms_side_on, max_zoom=1.1)

# %%
modeldata = ImageClassifierData.from_names_and_array(PATH, input_images, label_wordvecs, val_idxs=val_indcs, classes=None, tfms=tfms, continuous=True, bs=128)

# %%
x, y = next(iter(modeldata.val_dl))

# %%
x.shape, y.shape
# Out:
# (torch.Size([128, 3, 224, 224]), torch.Size([128, 300]))

# %%
modeldata.c
# Out:
# 300

# %%
opt_fn = partial(optim.Adam, betas=(0.9, 0.99))

# %%
mod2 = torchvision.models.resnet34(pretrained=True)

# %%
class WordVecPredictor(nn.Module):
    def __init__(self, base, p = 0.1):
        self.name = "test"
        super().__init__()
        self.base = nn.Sequential(*list(mod2.children())[:-2])
        for param in self.base:
            param.requires_grad = False
        
        self.adaptAvgPool = nn.AdaptiveAvgPool2d(output_size=(1,1))
        self.adaptMaxPool = nn.AdaptiveMaxPool2d(output_size=(1,1))
        self.batchNorm = nn.BatchNorm1d(num_features=1024)
        self.batchNorm2 = nn.BatchNorm1d(num_features=1024)

        self.drop = nn.Dropout(p)
        self.lin1 = nn.Linear(in_features=1024, out_features=1024, bias=True)
        self.lin2 = nn.Linear(in_features=1024, out_features=300, bias=True)
        
    def forward(self, x):
        x = self.base(x)
        x = torch.cat((self.adaptAvgPool(x), self.adaptMaxPool(x)), dim=1)
        x = x.view(x.size(0), -1)
        x = self.batchNorm(x)
        x = self.drop(x)
        x = torch.nn.functional.relu(x)
        x = self.batchNorm2(x)
        x = self.drop(x)
        return self.lin2(x)

# %%
model = WordVecPredictor(mod2)

# %%
def cos_loss(input, target):
    return 1 - F.cosine_similarity(input, target).mean()

# does not care about th lengths of the vectors, only the angle between them
# cosine sim returns 1 if two vectors point in same direction, 0 if angle is 90 degrees
# to convert to loss we do 1 - cosine sim so that the loss is smaller when the angle is smaller

# %%
crit = cos_loss

# %%
learn = Learner(modeldata, SingleModel(to_gpu(model)), opt_fn=opt_fn)

# %%
learn.freeze_to(-7)

# %%
learn.crit = crit

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#  16%|█▌        | 16/99 [00:08<00:41,  1.98it/s, loss=0.983]
# epoch      trn_loss   val_loss
#     0      0.603722   0.568249

# %%
learn.sched.plot(n_skip=0)

# %%
lr = 1e-2
wd = 1e-6

# %%
learn.fit(lr, 1, cycle_len=20, use_clr=(20,10))
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=20), HTML(value='')))
#   0%|          | 0/99 [00:00<?, ?it/s]
# epoch      trn_loss   val_loss
#     0      0.577125   1.246532
#     1      0.539636   0.530739
#     2      0.525656   0.520771
#  47%|████▋     | 47/99 [00:20<00:22,  2.31it/s, loss=0.522]

# %%
learn.save('model1')

# %%
learn.load('model1')

# %% [markdown]
# ## Searching images

# %% [markdown]
# ### Searching for imagenet classes

# %%
class_ids, wordvecs = list(zip(*imagenet_id2wordvec))  # this gives <1k results

# %%
class_ids[:5], wordvecs[0].shape

# %%
predicted_word_vecs = learn.predict()

# %%
len(predicted_word_vecs)
# Out:
# 1404

# %%
start=0

# %%
denorm = modeldata.val_ds.denorm

def show_img(im, figsize=None, ax=None):
    if not ax: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(im)
    ax.axis('off')
    return ax

def show_imgs(ims, cols, figsize=None):
    fig,axes = plt.subplots(len(ims)//cols, cols, figsize=figsize)
    for i,ax in enumerate(axes.flat): show_img(ims[i], ax=ax)
    plt.tight_layout()

# %% [markdown]
# **Let's take a look at a few validation images:**

# %%
show_imgs(denorm(modeldata.val_ds[start:start+6][0]), 3, (12,12))

# %%
import nmslib  # nearest neighbours search library that is REALLY fast!!

# %%
def create_index(a):
    index = nmslib.init(space='angulardist')
    index.addDataPointBatch(a)
    index.createIndex()
    return index

# %% [markdown]
# **The index is built from all the word vectors that belong to the Imagenet classes. Within this index we then find the nearest neighbours to our predicted wordvecs for an image.**

# %%
nearest_neighbour_index = create_index(wordvecs)

# %% [markdown]
# Given a vector `vec` (or several vectors `vecs`), these functions return the closest k vectors from the index:

# %%
def get_knn(index, vec):
    return index.knnQuery(vec, k=10)

# %%
def get_knns(index, vecs):
    return zip(*index.knnQueryBatch(vecs, k=10, num_threads=4))

# %% [markdown]
# Now we calculate the nearest neighbours of the predicted wordvectors of the images we just saw:

# %%
nn_indcs, dists = get_knns(nearest_neighbour_index, predicted_word_vecs)

# %% [markdown]
# These are the class names of the nearest neighbours of the predicted word vectors:

# %%
[[classIds_wordnet[class_ids[id]] for id in ids[:3]] for ids in nn_indcs[start:start+6]]
# Out:
# [['terrapin', 'loggerhead', 'badger'],
#  ['terrapin', 'loggerhead', 'diamondback'],
#  ['vulture', 'magpie', 'hyena'],
#  ['vulture', 'bustard', 'partridge'],
#  ['vulture', 'ostrich', 'bustard'],
#  ['vulture', 'magpie', 'spoonbill']]

# %% [markdown]
# **This is pretty cool:**
#
# 1. 'terrapin', 'loggerhead', 'diamondback' are all turtle types
# 2. Apart from 'hyena' all other nearest neighbours are birds which also makes sense if you look at the pictures

# %% [markdown]
# ### Search for all WordNet noun classes
# The last try was to search the nearest neighbours of our predictions only from the <1k imagenet classes. Now we do the same but with all WordNet noun classes.

# %%
class_ids_wordnet, wordvecs_wordnet = list(zip(*wordnet_id2wordvec))  # This gives ~50k results

# %%
len(wordnet_id2wordvec)
# Out:
# 49469

# %% [markdown]
# **The index is built from all the word vectors that belong to the WordNet classes. Within this index we then find the nearest neighbours to our predicted wordvecs for an image.**

# %%
nearest_neighbour_index_wordnet = create_index(wordvecs_wordnet)

# %%
nn_indcs, dists = get_knns(nearest_neighbour_index_wordnet, predicted_word_vecs)

# %%
[[classIds_wordnet[class_ids_wordnet[id]] for id in ids[:3]] for ids in nn_indcs[start:start+6]]
# Out:
# [['terrapin', 'turtle', 'alligator'],
#  ['terrapin', 'turtle', 'Malaclemys'],
#  ['vulture', 'Vultur', 'stork'],
#  ['vulture', 'bustard', 'partridge'],
#  ['vulture', 'ostrich', 'ostrich'],
#  ['vulture', 'Vultur', 'stork']]

# %% [markdown]
# **Wow, this works just as well :D 'Coragyps' is a bird too apparently**

# %%
classIds_wordnet
# Out:
# {'n00001740': 'entity',
#  'n00001930': 'physical_entity',
#  'n00002137': 'abstraction',
#  'n00002452': 'thing',
#  'n00002684': 'object',
#  'n00003553': 'whole',
#  'n00003993': 'congener',
#  'n00004258': 'living_thing',
#  'n00004475': 'organism',
#  'n00005787': 'benthos',
#  'n00005930': 'dwarf',
#  'n00006024': 'heterotroph',
#  'n00006150': 'parent',
#  'n00006269': 'life',
#  'n00006400': 'biont',
#  'n00006484': 'cell',
#  'n00007347': 'causal_agent',
#  'n00007846': 'person',
#  'n00015388': 'animal',
#  'n00017222': 'plant',
#  'n00019046': 'native',
#  'n00019128': 'natural_object',
#  'n00019613': 'substance',
#  'n00020090': 'substance',
#  'n00020827': 'matter',
#  'n00021265': 'food',
#  'n00021734': 'nutrient',
#  'n00021939': 'artifact',
#  'n00022903': 'article',
#  'n00023100': 'psychological_feature',
#  'n00023271': 'cognition',
#  'n00023773': 'motivation',
#  'n00024264': 'attribute',
#  'n00024720': 'state',
#  'n00026192': 'feeling',
#  'n00027167': 'location',
#  'n00027807': 'shape',
#  'n00028270': 'time',
#  'n00028651': 'space',
#  'n00029007': 'absolute_space',
#  'n00029114': 'phase_space',
#  'n00029378': 'event',
#  'n00029677': 'process',
#  'n00030358': 'act',
#  'n00031264': 'group',
#  'n00031921': 'relation',
#  'n00032613': 'possession',
#  'n00032823': 'social_relation',
#  'n00033020': 'communication',
#  'n00033615': 'measure',
#  'n00034213': 'phenomenon',
#  'n00034479': 'thing',
#  'n00034574': 'kindness',
#  'n00034777': 'abdominoplasty',
#  'n00034939': 'abort',
#  'n00035189': 'accomplishment',
#  'n00035697': 'agon',
#  'n00035891': 'alienation',
#  'n00036061': 'application',
#  'n00036299': 'beachhead',
#  'n00036580': 'cakewalk',
#  'n00036762': 'feat',
#  'n00037006': 'masterpiece',
#  'n00037090': 'masterstroke',
#  'n00037200': 'credit',
#  'n00037396': 'action',
#  'n00038175': 'res_gestae',
#  'n00038262': 'course',
#  'n00038573': 'blind_alley',
#  'n00038863': 'collision_course',
#  'n00039021': 'interaction',
#  'n00039211': 'interplay',
#  'n00039297': 'contact',
#  'n00039545': 'brush',
#  'n00039740': 'eye_contact',
#  'n00039916': 'fetch',
#  'n00039990': 'placement',
#  'n00040152': 'interchange',
#  'n00040420': 'reciprocity',
#  'n00040545': 'cross-fertilization',
#  'n00040804': 'dealings',
#  'n00040962': 'relation',
#  'n00041188': 'playing',
#  'n00041468': 'play',
#  'n00041614': 'boondoggle',
#  'n00041740': 'bowling',
#  'n00041899': 'acquiring',
#  'n00042311': 'causing',
#  'n00042541': 'delivery',
#  'n00042757': 'departure',
#  'n00043116': 'derring-do',
#  'n00043195': 'discovery',
#  'n00043609': 'disposal',
#  'n00043902': 'hit',
#  'n00044150': 'implementation',
#  'n00044455': 'egress',
#  'n00044673': 'equalization',
#  'n00044900': 'exhumation',
#  'n00045114': 'mitzvah',
#  'n00045250': 'propulsion',
#  'n00045646': 'rally',
#  'n00045907': 'recovery',
#  'n00046177': 'running_away',
#  'n00046344': 'stunt',
#  'n00046522': 'touch',
#  'n00047018': 'tour_de_force',
#  'n00047106': 'performance',
#  'n00047356': 'overachievement',
#  'n00047550': 'underachievement',
#  'n00047745': 'record',
#  'n00047941': 'fait_accompli',
#  'n00048051': 'going',
#  'n00048225': 'arrival',
#  'n00048374': 'arrival',
#  'n00048656': 'attainment',
#  'n00048828': 'advent',
#  'n00049003': 'entrance',
#  'n00049344': 'incursion',
#  'n00049530': 'intrusion',
#  'n00049636': 'irruption',
#  'n00049789': 'entree',
#  'n00049909': 'entail',
#  'n00050037': 'registration',
#  'n00050195': 'appearance',
#  'n00050484': 'apparition',
#  'n00050693': 'emergence',
#  'n00050887': 'reappearance',
#  'n00051077': 'comeback',
#  'n00051192': 'return',
#  'n00051385': 'repatriation',
#  'n00051525': 'penetration',
#  'n00051712': 'interpenetration',
#  'n00051897': 'market_penetration',
#  'n00052052': 'anchorage',
#  'n00052146': 'docking',
#  'n00052334': 'landing',
#  'n00052500': 'landing',
#  'n00052791': 'forced_landing',
#  'n00053020': 'breaking_away',
#  'n00053097': 'farewell',
#  'n00053405': 'French_leave',
#  'n00053525': 'valediction',
#  'n00053609': 'disappearance',
#  'n00053806': 'vanishing',
#  'n00053913': 'withdrawal',
#  'n00054328': 'effacement',
#  'n00054483': 'retreat',
#  'n00054652': 'retirement',
#  'n00054821': 'evacuation',
#  'n00055038': 'medical_evacuation',
#  'n00055227': 'decampment',
#  'n00055315': 'desertion',
#  'n00055633': 'abscondment',
#  'n00055793': 'absence_without_leave',
#  'n00055932': 'deviationism',
#  'n00056087': 'emigration',
#  'n00056311': 'immigration',
#  'n00056551': 'aliyah',
#  'n00056688': 'pullback',
#  'n00056912': 'retreat',
#  'n00057162': 'standdown',
#  'n00057306': 'disengagement',
#  'n00057486': 'receding',
#  'n00057657': 'sailing',
#  'n00057748': 'amphibious_landing',
#  'n00058002': 'debarkation',
#  'n00058247': 'going_ashore',
#  'n00058337': 'boarding',
#  'n00058519': 'exit',
#  'n00058608': 'elopement',
#  'n00058743': 'escape',
#  'n00059127': 'evasion',
#  'n00059376': 'slip',
#  'n00059552': 'maneuver',
#  'n00059728': 'clinch',
#  'n00059895': 'dodge',
#  'n00059989': 'break',
#  'n00060201': 'getaway',
#  'n00060414': 'exodus',
#  'n00060548': 'Hegira',
#  'n00060747': 'skedaddle',
#  'n00060817': 'Underground_Railroad',
#  'n00061014': 'close_call',
#  'n00061171': 'surfacing',
#  'n00061290': 'dispatch',
#  'n00061453': 'reshipment',
#  'n00061598': 'consummation',
#  'n00061792': 'consummation',
#  'n00061917': 'realization',
#  'n00062133': 'orgasm',
#  'n00062331': 'male_orgasm',
#  'n00062451': 'fulfillment',
#  'n00062671': 'self-fulfillment',
#  'n00062806': 'attainment',
#  'n00063014': 'record',
#  'n00063310': 'track_record',
#  'n00063559': 'world_record',
#  'n00063652': 'success',
#  'n00064018': 'winning',
#  'n00064151': 'blockbuster',
#  'n00064370': 'sleeper',
#  'n00064504': 'hit',
#  'n00064789': 'bell_ringer',
#  'n00065098': 'ennoblement',
#  'n00065216': 'conquest',
#  'n00065336': 'coup',
#  'n00065418': 'flying_colors',
#  'n00065575': 'passing',
#  'n00065855': 'credit',
#  'n00066075': 'semester_hour',
#  'n00066216': 'nonaccomplishment',
#  'n00066397': 'failure',
#  'n00066636': 'failure',
#  'n00066901': 'failing',
#  'n00067153': 'naught',
#  'n00067254': 'cut',
#  'n00067397': 'default',
#  'n00067526': 'loss',
#  'n00067707': 'capitulation',
#  'n00067990': 'frustration',
#  'n00068170': 'overturn',
#  'n00068333': 'backsliding',
#  'n00068617': 'recidivism',
#  'n00068755': 'disappointment',
#  'n00068901': 'breach',
#  'n00069060': 'copout',
#  'n00069173': 'breach_of_contract',
#  'n00069444': 'anticipatory_breach',
#  'n00069604': 'breach_of_duty',
#  'n00069685': 'breach_of_the_covenant_of_warranty',
#  'n00069815': 'breach_of_promise',
#  'n00069918': 'breach_of_trust',
#  'n00070077': 'breach_of_trust_with_fraudulent_intent',
#  'n00070215': 'breach_of_warranty',
#  'n00070363': 'leaning',
#  'n00070462': 'material_breach',
#  'n00070641': 'motivation',
#  'n00070807': 'partial_breach',
#  'n00070965': 'mistake',
#  'n00071546': 'double_fault',
#  'n00071700': 'footfault',
#  'n00071864': 'bobble',
#  'n00072068': 'error',
#  'n00072261': 'blot',
#  'n00072473': 'confusion',
#  'n00072691': 'incursion',
#  'n00072808': 'miscalculation',
#  'n00073032': 'backfire',
#  'n00073177': 'rounding',
#  'n00073525': 'truncation_error',
#  'n00073713': 'distortion',
#  'n00073828': 'slip',
#  'n00074092': 'Freudian_slip',
#  'n00074324': 'offside',
#  'n00074524': 'oversight',
#  'n00074624': 'omission',
#  'n00074790': 'blunder',
#  'n00075283': 'snafu',
#  'n00075471': 'spectacle',
#  'n00075618': 'ballup',
#  'n00075790': 'bull',
#  'n00075912': 'fumble',
#  'n00076072': 'fluff',
#  'n00076196': 'faux_pas',
#  'n00076323': 'howler',
#  'n00076393': 'clanger',
#  'n00076563': 'trip',
#  'n00076884': 'spill',
#  'n00077169': 'pratfall',
#  'n00077249': 'wipeout',
#  'n00077419': 'acquisition',
#  'n00077856': 'obtainment',
#  'n00077981': 'catching',
#  'n00078217': 'incurring',
#  'n00078393': 'moneymaking',
#  'n00078536': 'annexation',
#  'n00078821': 'pork-barreling',
#  'n00079018': 'purchase',
#  'n00079212': 'redemption',
#  'n00079398': 'trading',
#  'n00079603': 'bond_trading',
#  'n00079752': 'program_trading',
#  'n00079908': 'short_sale',
#  'n00080096': 'short_covering',
#  'n00080242': 'insider_trading',
#  'n00080474': 'naked_option',
#  'n00080619': 'covered_option',
#  'n00080743': 'call_option',
#  'n00080968': 'put_option',
#  'n00081174': 'straddle',
#  'n00081395': 'incentive_option',
#  'n00081572': 'buying',
#  'n00081836': 'shopping',
#  'n00082081': 'marketing',
#  'n00082223': 'mail-order_buying',
#  'n00082347': 'viatication',
#  'n00082525': 'acceptance',
#  'n00082754': 'succession',
#  'n00082870': 'assumption',
#  'n00083260': 'assumption',
#  'n00083448': 'position',
#  'n00083585': 'inheritance',
#  'n00083729': 'procurement',
#  'n00083975': 'appropriation',
#  'n00084371': 'borrowing',
#  'n00084642': 'naturalization',
#  'n00084895': 'misappropriation',
#  'n00085041': 'preemption',
#  'n00085219': 'seizure',
#  'n00085432': 'usurpation',
#  'n00085678': 'confiscation',
#  'n00085829': 'distress',
#  'n00086140': 'expropriation',
#  'n00086297': 'impoundment',
#  'n00086547': 'drug_bust',
#  'n00086654': 'impress',
#  'n00086809': 'occupation',
#  'n00087073': 'preoccupancy',
#  'n00087218': 'sequestration',
#  'n00087423': 'grant',
#  'n00087663': 'award',
#  'n00087849': 'addiction',
#  'n00088154': 'block_grant',
#  'n00088367': 'grant-in-aid',
#  'n00088481': 'capture',
#  'n00088725': 'apprehension',
#  'n00089027': 'conquest',
#  'n00089234': 'enslavement',
#  'n00089351': 'restitution',
#  'n00089657': 'clawback',
#  'n00089891': 'repossession',
#  'n00090076': 'foreclosure',
#  'n00090253': 'reception',
#  'n00090393': 'appointment',
#  'n00090610': 'comb-out',
#  'n00090779': 'giving',
#  'n00091013': 'abandonment',
#  'n00091234': 'discard',
#  'n00091404': 'staging',
#  'n00091503': 'discard',
#  'n00091670': 'mine_disposal',
#  'n00091779': 'minesweeping',
#  'n00091893': 'sewage_disposal',
#  'n00091977': 'bait_and_switch',
#  'n00092212': 'private_treaty',
#  'n00092366': 'auction',
#  'n00092663': 'bootlegging',
#  'n00092847': 'bootlegging',
#  'n00093006': 'capitalization',
#  'n00093127': 'overcapitalization',
#  'n00093354': 'reclamation',
#  'n00093483': 'rescue',
#  'n00093874': 'lifesaving',
#  'n00094001': 'redemption',
#  'n00094240': 'absolution',
#  'n00094500': 'indulgence',
#  'n00094788': 'conversion',
#  'n00094954': 'proselytism',
#  'n00095121': 'expiation',
#  'n00095329': 'reparation',
#  'n00095502': 'liberation',
#  'n00095873': 'jail_delivery',
#  'n00095971': 'reclamation',
#  'n00096211': 'salvage',
#  'n00096343': 'salvage',
#  'n00096513': 'salvation',
#  'n00096720': 'search_and_rescue_mission',
#  'n00096851': 'ransom',
#  'n00096969': 'recapture',
#  'n00097122': 'recapture',
#  'n00097244': 'invocation',
#  'n00097348': 'instrumentation',
#  'n00097504': 'performance',
#  'n00097923': 'specific_performance',
#  'n00098051': 'linguistic_performance',
#  'n00098385': 'mechanism',
#  'n00098625': 'service',
#  'n00098822': 'curb_service',
#  'n00098939': 'self-service',
#  'n00099061': 'valet_parking',
#  'n00099267': 'dramatic_production',
#  'n00099439': 'encore',
#  'n00099588': 'extemporization',
#  'n00099799': 'juggle',
#  'n00099951': 'magic_trick',
#  'n00100253': 'musical_performance',
#  'n00100437': 'one-night_stand',
#  'n00100543': 'rendition',
#  'n00100889': 'reinterpretation',
#  'n00101003': 'spin',
#  'n00101191': 'playing',
#  'n00101410': 'bowing',
#  'n00101570': 'spiccato',
#  'n00101708': 'piping',
#  'n00101809': 'stopping',
#  'n00102039': 'double_stopping',
#  'n00102162': 'transposition',
#  'n00102374': 'jam_session',
#  'n00102457': 'automation',
#  'n00102779': 'computerization',
#  'n00102927': 'motorization',
#  'n00103140': 'launching',
#  'n00103291': 'launching',
#  'n00103419': 'rocket_firing',
#  'n00103590': 'blastoff',
#  'n00103737': 'moon_shot',
#  'n00103834': 'drive',
#  'n00104088': 'firewall',
#  'n00104249': 'impulse',
#  'n00104409': 'roll',
#  'n00104539': 'throw',
#  'n00104976': 'bowling',
#  'n00105164': 'fling',
#  'n00105271': 'heave',
#  'n00105479': 'hurl',
#  'n00105624': 'leaner',
#  'n00105820': 'pass',
#  'n00106104': 'pitch',
#  'n00106272': 'pitch',
#  'n00106726': 'ringer',
#  'n00106888': 'shy',
#  'n00107016': 'slinging',
#  'n00107137': 'throw-in',
#  'n00107279': 'balk',
#  'n00107400': 'ball',
#  'n00107551': 'beanball',
#  'n00107684': 'change-up',
#  'n00107875': 'curve',
#  'n00108081': 'duster',
#  'n00108181': 'fastball',
#  'n00108427': 'knuckleball',
#  'n00108545': 'overhand_pitch',
#  'n00108665': 'passed_ball',
#  'n00108818': 'screwball',
#  'n00108965': 'sinker',
#  'n00109081': 'slider',
#  'n00109227': 'spitball',
#  'n00109414': 'strike',
#  'n00109771': 'submarine_ball',
#  'n00109892': 'wild_pitch',
#  'n00110057': 'basketball_shot',
#  'n00110415': 'bank_shot',
#  'n00110554': 'dunk',
#  'n00110745': 'slam_dunk',
#  'n00110834': 'finger-roll',
#  'n00110964': 'foul_shot',
#  'n00111222': 'one-and-one',
#  'n00111358': 'hook_shot',
#  'n00111503': 'jumper',
#  'n00111660': 'lay-up',
#  'n00111839': 'pivot_shot',
#  'n00111962': 'set_shot',
#  'n00112072': 'scoop_shot',
#  'n00112185': 'tip_in',
#  'n00112312': 'push',
#  'n00112674': 'depression',
#  'n00112828': 'click',
#  'n00112997': 'nudge',
#  'n00113113': 'press',
#  'n00113532': 'impression',
#  'n00113726': 'shove',
#  'n00113954': 'bundling',
#  'n00114095': 'jostle',
#  'n00114298': 'elbowing',
#  'n00114431': 'pull',
#  'n00114871': 'drag',
#  'n00115036': 'draw',
#  'n00115292': 'tow',
#  'n00115500': 'tug',
#  'n00115667': 'draft',
#  'n00115803': 'extirpation',
#  'n00116008': 'pluck',
#  'n00116122': 'traction',
#  'n00116376': 'lift',
#  'n00116687': 'expulsion',
#  'n00116989': 'defenestration',
#  'n00117124': 'accommodation_reflex',
#  'n00117267': 'Babinski',
#  'n00117578': 'belch',
#  'n00117810': 'belching',
#  'n00117959': 'blink',
#  'n00118268': 'blush',
#  'n00118445': 'coughing_up',
#  'n00118552': 'spit',
#  'n00118733': 'vomit',
#  'n00119079': 'rumination',
#  'n00119210': 'hematemesis',
#  'n00119297': 'hyperemesis',
#  'n00119402': 'hyperemesis_gravidarum',
#  'n00119568': 'jump',
#  'n00119893': 'header',
#  'n00120010': 'hop',
#  'n00120202': 'leap',
#  'n00120515': 'vault',
#  'n00120647': 'jumping_up_and_down',
#  'n00120804': 'lob',
#  'n00120943': 'centering',
#  'n00121166': 'sending',
#  'n00121366': 'transmission',
#  'n00121645': 'forwarding',
#  'n00121904': 'referral',
#  'n00122106': 'remission',
#  'n00122338': 'mailing',
#  'n00122530': 'wheeling',
#  'n00122661': 'shooting',
#  'n00122954': 'shoot',
#  'n00123143': 'countershot',
#  'n00123234': 'discharge',
#  'n00123430': 'gun',
#  'n00123652': 'fire_control',
#  'n00123783': 'gunfire',
#  'n00124008': 'enfilade',
#  'n00124151': 'snipe',
#  'n00124256': 'headshot',
#  'n00124342': 'skeet',
#  'n00124536': 'shellfire',
#  'n00124617': 'gunfight',
#  'n00124766': 'potshot',
#  'n00124880': 'contact',
#  'n00125126': 'rub',
#  'n00125315': 'scuff',
#  'n00125436': 'tap',
#  'n00125629': 'hit',
#  'n00126100': 'contusion',
#  'n00126236': 'crash',
#  'n00126447': 'impingement',
#  'n00126584': 'batting',
#  'n00126721': 'fielding',
#  'n00126886': 'catching',
#  'n00127021': 'golfing',
#  'n00127151': 'pitching',
#  'n00127286': 'base_on_balls',
#  'n00127531': 'best',
#  'n00127672': 'worst',
#  'n00127866': 'fair_ball',
#  'n00128091': 'foul_ball',
#  'n00128324': 'snick',
#  'n00128477': 'bunt',
#  'n00128638': 'fly',
#  'n00128867': 'blast',
#  'n00128976': 'pop_fly',
#  'n00129089': 'grounder',
#  'n00129317': 'chop',
#  'n00129435': 'roller',
#  'n00129527': 'out',
#  'n00129743': 'force_out',
#  'n00130093': 'putout',
#  'n00130347': 'strikeout',
#  'n00130512': 'whiff',
#  'n00130673': "fielder's_choice",
#  'n00130846': 'sacrifice',
#  'n00130987': 'sacrifice_fly',
#  'n00131090': 'base_hit',
#  'n00131347': 'daisy_cutter',
#  'n00131485': 'header',
#  'n00131608': 'liner',
#  'n00131791': 'scorcher',
#  'n00131877': 'line-drive_single',
#  'n00131991': 'line-drive_double',
#  'n00132105': 'line-drive_triple',
#  'n00132219': 'plunk',
#  'n00132355': 'homer',
#  'n00132497': 'solo_homer',
#  'n00132601': 'single',
#  'n00132756': 'double',
#  'n00132982': 'triple',
#  'n00133160': 'backhander',
#  'n00133234': 'clip',
#  'n00133338': 'knock',
#  'n00133567': 'thwack',
#  'n00133668': 'smack',
#  'n00133875': 'smacker',
#  'n00133981': 'knockdown',
#  'n00134099': 'knockout',
#  'n00134246': 'technical_knockout',
#  'n00134391': 'swat',
#  'n00134472': 'spank',
#  'n00134574': 'whip',
#  'n00134780': 'punch',
#  'n00135148': 'box',
#  'n00135311': 'dig',
#  'n00135504': 'counterpunch',
#  'n00135637': 'haymaker',
#  'n00135799': 'hook',
#  'n00135952': 'jab',
#  'n00136048': 'rabbit_punch',
#  'n00136152': 'sucker_punch',
#  'n00136230': 'roundhouse',
#  'n00136329': 'kick',
#  'n00136691': 'goal-kick',
#  'n00136876': 'goal-kick',
#  'n00136984': 'punt',
#  'n00137279': 'place_kick',
#  'n00137534': 'free_kick',
#  'n00137709': 'corner_kick',
#  'n00137877': 'dropkick',
#  'n00138078': 'kiss',
#  'n00138221': 'kiss',
#  'n00138441': 'laying_on',
#  'n00138599': 'smack',
#  'n00138734': 'smacker',
#  'n00138799': 'soul_kiss',
#  'n00138956': 'catch',
#  'n00139544': 'fair_catch',
#  'n00139758': 'interception',
#  'n00139919': 'reception',
#  'n00140112': 'rebound',
#  'n00140264': 'shoestring_catch',
#  'n00140393': 'mesh',
#  'n00140652': 'handling',
#  'n00140900': 'fingering',
#  'n00141027': 'grope',
#  'n00141176': 'audit',
#  'n00141396': 'autopsy',
#  'n00141669': 'check-in',
#  'n00141806': 'check',
#  'n00142140': 'spot_check',
#  'n00142361': 'checkup',
#  'n00142665': 'comparison',
#  'n00143057': 'fine-tooth_comb',
#  'n00143251': 'follow-up',
#  'n00143536': 'going-over',
#  'n00143626': 'once-over',
#  'n00143763': 'ophthalmoscopy',
#  'n00143885': 'palpation',
#  'n00144182': 'ballottement',
#  'n00144445': 'tickle',
#  'n00144632': 'stroke',
#  'n00144778': 'caress',
#  'n00145024': 'tag',
#  'n00145218': 'joining',
#  'n00145779': 'hit',
#  'n00145929': 'interconnection',
#  'n00146111': 'intersection',
#  'n00146277': 'approximation',
#  'n00146443': 'concatenation',
#  'n00146572': 'convergence',
#  'n00146856': 'merging',
#  'n00147091': 'concourse',
#  'n00147187': 'encounter',
#  'n00147314': 'articulation',
#  'n00147454': 'junction',
#  'n00147595': 'fastening',
#  'n00147862': 'loosening',
#  'n00148057': 'tightening',
#  'n00148242': 'ligation',
#  'n00148446': 'tubal_ligation',
#  'n00148653': 'bonding',
#  'n00148762': 'doweling',
#  'n00148836': 'grounding',
#  'n00148978': 'linkage',
#  'n00149084': 'tying',
#  'n00149262': 'untying',
#  'n00149508': 'welding',
#  'n00149699': 'butt_welding',
#  'n00149895': 'spot_welding',
#  'n00150097': 'flare',
#  'n00150228': 'Texas_leaguer',
#  'n00150379': 'flash_welding',
#  'n00150591': 'lick',
#  'n00150762': 'grazing',
#  'n00150932': 'tracing',
#  'n00151087': 'detection',
#  'n00151314': 'self-discovery',
#  'n00151409': 'breakthrough',
#  'n00151497': 'determination',
#  'n00151914': 'rediscovery',
#  'n00152018': 'designation',
#  'n00152230': 'Bertillon_system',
#  'n00152338': 'fingerprinting',
#  'n00152519': 'genetic_profiling',
#  'n00152727': 'diagnosis',
#  'n00152990': 'blood_typing',
#  'n00153105': 'medical_diagnosis',
#  'n00153288': 'prenatal_diagnosis',
#  'n00153499': 'differential_diagnosis',
#  'n00153665': 'prognosis',
#  'n00153809': 'resolution',
#  'n00153961': 'validation',
#  'n00154233': 'authentication',
#  'n00154433': 'documentation',
#  'n00154689': 'monetization',
#  'n00154894': 'probate',
#  'n00155085': 'demonetization',
#  'n00155298': 'falsification',
#  'n00155487': 'localization',
#  'n00155797': 'echolocation',
#  'n00155970': 'predetermination',
#  'n00156119': 'rectification',
#  'n00156293': 'redetermination',
#  'n00156390': 'trigger',
#  'n00156625': 'fomentation',
#  'n00156812': 'compulsion',
#  'n00157081': 'influence',
#  'n00157318': 'cross-pollination',
#  'n00157463': 'exposure',
#  'n00157687': 'overexposure',
#  'n00157877': 'underexposure',
#  'n00157957': 'impingement',
#  'n00158185': 'manipulation',
#  'n00158443': 'mind_game',
#  'n00158805': 'autosuggestion',
#  'n00158996': 'hypnotism',
#  'n00159177': 'inducement',
#  'n00159396': 'corruption',
#  'n00159620': 'enticement',
#  'n00159899': 'blandishment',
#  'n00160073': 'ingratiation',
#  'n00160297': 'leading_astray',
#  'n00160415': 'seduction',
#  'n00160532': 'seduction',
#  'n00160688': 'sexual_conquest',
#  'n00160922': 'cuckoldry',
#  'n00161044': 'solicitation',
#  'n00161243': 'choice',
#  'n00161603': 'casting',
#  'n00161739': 'coloration',
#  'n00161888': 'sampling',
#  'n00162055': 'random_sampling',
#  'n00162236': 'lucky_dip',
#  'n00162417': 'stratified_sampling',
#  'n00162632': 'decision',
#  'n00163047': 'volition',
#  'n00163233': 'intention',
#  'n00163406': 'about-face',
#  'n00163630': 'adulteration',
#  'n00163779': 'appointment',
#  'n00164152': 'nomination',
#  'n00164345': 'assignment',
#  'n00164579': 'allocation',
#  'n00164801': 'call',
#  'n00164999': 'co-option',
#  'n00165178': 'delegacy',
#  'n00165298': 'ordination',
#  'n00165563': 'recognition',
#  'n00165793': 'laying_on_of_hands',
#  'n00165942': 'move',
#  'n00166172': 'move',
#  'n00166355': 'chess_move',
#  'n00166552': 'castle',
#  'n00166702': 'capture',
#  'n00166865': 'en_passant',
#  'n00167063': 'exchange',
#  'n00167278': 'exchange',
#  'n00167446': 'check',
#  'n00167580': 'discovered_check',
#  'n00167764': 'checkmate',
#  'n00167950': 'gambit',
#  'n00168121': 'demarche',
#  'n00168237': 'maneuver',
#  'n00168505': 'parking',
#  'n00168658': 'move',
#  'n00168911': 'flit',
#  'n00169047': 'downshift',
#  'n00169147': 'downshift',
#  'n00169305': 'bank',
#  'n00169522': 'vertical_bank',
#  'n00169651': 'chandelle',
#  'n00169811': 'loop',
#  'n00170005': 'inside_loop',
#  'n00170172': 'outside_loop',
#  'n00170340': 'roll',
#  'n00170536': 'barrel_roll',
#  'n00170643': 'snap_roll',
#  'n00170710': 'slip',
#  'n00170844': 'flight_maneuver',
#  'n00171050': 'straight-arm',
#  'n00171249': 'device',
#  'n00171507': 'mnemonic',
#  'n00171618': 'trick',
#  'n00171882': 'shtik',
#  'n00172073': 'feint',
#  'n00172217': 'juke',
#  'n00172347': 'footwork',
#  'n00172490': 'ploy',
#  'n00172598': 'ruse',
#  'n00172710': 'means',
#  'n00173172': 'dint',
#  'n00173283': 'escape',
#  'n00173487': 'fast_track',
#  'n00173761': 'instrument',
#  'n00174003': 'road',
#  'n00174127': 'royal_road',
#  'n00174260': 'stepping_stone',
#  'n00174412': 'measure',
#  'n00174663': 'countermeasure',
#  'n00174782': 'bear_hug',
#  'n00174950': 'proxy_fight',
#  'n00175174': 'leveraged_buyout',
#  'n00175433': 'bust-up_takeover',
#  'n00175605': 'shark_repellent',
#  'n00175875': 'golden_parachute',
#  'n00176052': 'greenmail',
#  'n00176312': 'pac-man_strategy',
#  'n00176449': 'poison_pill',
#  'n00176609': 'suicide_pill',
#  'n00176766': 'safe_harbor',
#  'n00176994': 'scorched-earth_policy',
#  'n00177127': 'diagnostic_procedure',
#  'n00177448': 'expedient',
#  'n00177638': 'backstop',
#  'n00177783': 'emergency_procedure',
#  'n00178024': 'experimental_procedure',
#  'n00178177': 'double-blind_procedure',
#  'n00178551': 'makeshift',
#  'n00178700': 'crutch',
#  'n00178832': 'improvisation',
#  'n00178972': 'pis_aller',
#  'n00179125': 'desperate_measure',
#  'n00179275': 'open_sesame',
#  'n00179380': 'salvation',
#  'n00179576': 'tooth',
#  'n00179683': 'voice',
#  'n00179916': 'wings',
#  'n00180054': 'casting_lots',
#  'n00180228': 'resolution',
#  'n00180413': 'adoption',
#  'n00180770': 'embrace',
#  'n00180962': 'election',
#  'n00181191': 'co-option',
#  'n00181373': 'reelection',
#  'n00181495': 'plebiscite',
#  'n00181640': 'referendum',
#  'n00181781': 'election',
#  'n00182213': 'vote',
#  'n00182435': 'general_election',
#  'n00182571': 'primary',
#  'n00182723': 'direct_primary',
#  'n00182897': 'closed_primary',
#  'n00183084': 'open_primary',
#  'n00183240': 'by-election',
#  'n00183357': 'runoff',
#  'n00183505': 'vote',
#  'n00183995': 'block_vote',
#  'n00184135': 'cumulative_vote',
#  'n00184362': 'secret_ballot',
#  'n00184501': 'split_ticket',
#  'n00184652': 'straight_ticket',
#  'n00184802': 'multiple_voting',
#  'n00184981': 'casting_vote',
#  'n00185104': 'reconciliation',
#  'n00185307': 'equation',
#  'n00185438': 'breech_delivery',
#  'n00185612': 'frank_breech',
#  'n00185778': 'cesarean_delivery',
#  'n00186251': 'forceps_delivery',
#  'n00186549': 'midwifery',
#  'n00186634': 'score',
#  'n00187056': 'bowling_score',
#  'n00187144': "bull's_eye",
#  'n00187337': 'goal',
#  'n00187499': 'own_goal',
#  'n00187710': 'strike',
#  'n00187890': 'spare',
#  'n00188007': 'open_frame',
#  'n00188183': 'audible',
#  'n00188341': 'football_score',
#  'n00188449': 'touchback',
#  'n00188620': 'safety',
#  'n00188766': 'touchdown',
#  'n00188934': 'field_goal',
#  'n00189106': 'conversion',
#  'n00189257': 'point_after',
#  'n00189476': 'baseball_score',
#  'n00189565': 'run',
#  'n00189896': 'earned_run',
#  'n00190040': 'unearned_run',
#  'n00190180': 'run_batted_in',
#  'n00190338': 'basketball_score',
#  'n00190431': 'basket',
#  'n00190579': 'hat_trick',
#  'n00190783': 'solution',
#  'n00190931': 'Russian_roulette',
#  'n00191142': 'change',
#  'n00191980': 'filtration',
#  'n00192149': 'percolation',
#  'n00192300': 'reduction',
#  'n00192457': 'schematization',
#  'n00192613': 'economy',
#  'n00192910': 'retrenchment',
#  'n00193099': 'economy_of_scale',
#  'n00193225': 'accommodation',
#  'n00193406': 'adaptation',
#  'n00193622': 'dark_adaptation',
#  'n00193811': 'light_adaptation',
#  'n00194005': 'take-up',
#  'n00194127': 'readjustment',
#  'n00194257': 'domestication',
#  'n00194414': 'decimalization',
#  'n00194645': 'metrification',
#  'n00194831': 'habituation',
#  'n00194969': 'variation',
#  'n00195194': 'variation',
#  'n00195415': 'turning',
#  'n00195569': 'diversification',
#  'n00195938': 'flux',
#  'n00196084': 'switch',
#  'n00196402': 'switcheroo',
#  'n00196485': 'substitution',
#  'n00196848': 'novation',
#  'n00197136': 'pitching_change',
#  'n00197229': 'superannuation',
#  'n00197419': 'supersedure',
#  'n00197610': 'supplanting',
#  'n00197772': 'replacement',
#  'n00198118': 'subrogation',
#  'n00198270': 'weaning',
#  'n00198451': 'promotion',
#  'n00198631': 'preferment',
#  'n00198793': 'demotion',
#  'n00198919': 'investment',
#  'n00199130': 'change_of_state',
#  'n00199707': 'alteration',
#  'n00200041': 'distraction',
#  'n00200244': 'aeration',
#  'n00200379': 'modulation',
#  'n00200563': 'qualification',
#  'n00200768': 'reorganization',
#  'n00201058': 'passage',
#  'n00201269': 'fossilization',
#  'n00201397': 'segue',
#  'n00201516': 'meddling',
#  'n00201671': 'transfer',
#  'n00201923': 'prohibition',
#  'n00202284': 'resistance',
#  'n00202620': 'lockout',
#  'n00202816': 'reaction',
#  'n00203020': 'backlash',
#  'n00203208': 'whitelash',
#  'n00203342': 'rejection',
#  'n00203649': 'brush-off',
#  'n00203753': 'avoidance',
#  'n00204022': 'aversion',
#  'n00204199': 'escape',
#  'n00204334': 'near_thing',
#  'n00204439': 'abandonment',
#  'n00204659': 'exposure',
#  'n00204814': 'apostasy',
#  'n00204943': 'bolt',
#  'n00205079': 'renunciation',
#  'n00205349': 'nonacceptance',
#  'n00205543': 'forsaking',
#  'n00205649': 'abnegation',
#  'n00205891': 'forfeit',
#  'n00206130': 'boycott',
#  'n00206302': 'banishment',
#  'n00206600': 'anathematization',
#  'n00206779': 'disbarment',
#  'n00206927': 'ejection',
#  'n00207306': 'deportation',
#  'n00207434': 'ostracism',
#  'n00207622': 'barring',
#  'n00207761': 'exile',
#  'n00208141': 'Babylonian_Captivity',
#  'n00208277': 'excommunication',
#  'n00208521': 'relegation',
#  'n00208694': 'rustication',
#  'n00208797': 'ouster',
#  'n00208943': 'deposition',
#  'n00209132': 'suspension',
#  'n00209301': 'rustication',
#  'n00209446': 'displacement',
#  'n00209546': 'veto',
#  'n00209680': 'pocket_veto',
#  'n00209789': 'write-in',
#  'n00209943': 'termination',
#  'n00210518': 'finish',
#  'n00210797': 'finale',
#  'n00210940': 'release',
#  'n00211110': 'completion',
#  'n00211462': 'finalization',
#  'n00211593': 'follow-through',
#  'n00211776': 'follow-through',
#  'n00212065': 'graduation',
#  'n00212205': 'retirement',
#  'n00212377': 'hibernation',
#  'n00212551': 'rustication',
#  'n00212678': 'swan_song',
#  'n00212808': 'relinquishment',
#  'n00213052': 'cession',
#  'n00213186': 'handover',
#  'n00213343': 'surrender',
#  'n00213482': 'extradition',
#  'n00213694': 'release',
#  'n00213903': 'exemption',
#  'n00214148': 'fix',
#  'n00214315': 'official_immunity',
#  'n00214526': 'sovereign_immunity',
#  'n00214794': 'transactional_immunity',
#  'n00215013': 'use_immunity',
#  'n00215314': 'dissolution',
#  'n00215534': 'splitsville',
#  'n00215683': 'overthrow',
#  'n00215838': 'subversion',
#  'n00216038': 'adjournment',
#  'n00216174': 'dismissal',
#  'n00216607': 'conge',
#  'n00216723': 'removal',
#  'n00216834': 'purge',
#  'n00217014': 'destruction',
#  ...}

# %%
class_ids_wordnet
# Out:
# ('n00001740',
#  'n00002137',
#  'n00002452',
#  'n00002684',
#  'n00003553',
#  'n00003993',
#  'n00004475',
#  'n00005787',
#  'n00005930',
#  'n00006024',
#  'n00006150',
#  'n00006269',
#  'n00006484',
#  'n00007846',
#  'n00015388',
#  'n00017222',
#  'n00019046',
#  'n00019613',
#  'n00020090',
#  'n00020827',
#  'n00021265',
#  'n00021734',
#  'n00021939',
#  'n00022903',
#  'n00023271',
#  'n00023773',
#  'n00024264',
#  'n00024720',
#  'n00026192',
#  'n00027167',
#  'n00027807',
#  'n00028270',
#  'n00028651',
#  'n00029378',
#  'n00029677',
#  'n00030358',
#  'n00031264',
#  'n00031921',
#  'n00032613',
#  'n00033020',
#  'n00033615',
#  'n00034213',
#  'n00034479',
#  'n00034574',
#  'n00034777',
#  'n00034939',
#  'n00035189',
#  'n00035697',
#  'n00035891',
#  'n00036061',
#  'n00036299',
#  'n00036580',
#  'n00036762',
#  'n00037006',
#  'n00037090',
#  'n00037200',
#  'n00037396',
#  'n00038262',
#  'n00039021',
#  'n00039211',
#  'n00039297',
#  'n00039545',
#  'n00039916',
#  'n00039990',
#  'n00040152',
#  'n00040420',
#  'n00040804',
#  'n00040962',
#  'n00041188',
#  'n00041468',
#  'n00041614',
#  'n00041740',
#  'n00041899',
#  'n00042311',
#  'n00042541',
#  'n00042757',
#  'n00043195',
#  'n00043609',
#  'n00043902',
#  'n00044150',
#  'n00044455',
#  'n00044673',
#  'n00044900',
#  'n00045114',
#  'n00045250',
#  'n00045646',
#  'n00045907',
#  'n00046344',
#  'n00046522',
#  'n00047106',
#  'n00047356',
#  'n00047550',
#  'n00047745',
#  'n00048051',
#  'n00048225',
#  'n00048374',
#  'n00048656',
#  'n00048828',
#  'n00049003',
#  'n00049344',
#  'n00049530',
#  'n00049636',
#  'n00049789',
#  'n00049909',
#  'n00050037',
#  'n00050195',
#  'n00050484',
#  'n00050693',
#  'n00050887',
#  'n00051077',
#  'n00051192',
#  'n00051385',
#  'n00051525',
#  'n00051712',
#  'n00052052',
#  'n00052146',
#  'n00052334',
#  'n00052500',
#  'n00053097',
#  'n00053525',
#  'n00053609',
#  'n00053806',
#  'n00053913',
#  'n00054328',
#  'n00054483',
#  'n00054652',
#  'n00054821',
#  'n00055315',
#  'n00055932',
#  'n00056087',
#  'n00056311',
#  'n00056551',
#  'n00056688',
#  'n00056912',
#  'n00057162',
#  'n00057306',
#  'n00057486',
#  'n00057657',
#  'n00058002',
#  'n00058337',
#  'n00058519',
#  'n00058608',
#  'n00058743',
#  'n00059127',
#  'n00059376',
#  'n00059552',
#  'n00059728',
#  'n00059895',
#  'n00059989',
#  'n00060201',
#  'n00060414',
#  'n00060548',
#  'n00060747',
#  'n00061171',
#  'n00061290',
#  'n00061598',
#  'n00061792',
#  'n00061917',
#  'n00062133',
#  'n00062451',
#  'n00062806',
#  'n00063014',
#  'n00063652',
#  'n00064018',
#  'n00064151',
#  'n00064370',
#  'n00064504',
#  'n00065098',
#  'n00065216',
#  'n00065336',
#  'n00065575',
#  'n00065855',
#  'n00066397',
#  'n00066636',
#  'n00066901',
#  'n00067153',
#  'n00067254',
#  'n00067397',
#  'n00067526',
#  'n00067707',
#  'n00067990',
#  'n00068170',
#  'n00068333',
#  'n00068617',
#  'n00068755',
#  'n00068901',
#  'n00069060',
#  'n00070363',
#  'n00070641',
#  'n00070965',
#  'n00071864',
#  'n00072068',
#  'n00072261',
#  'n00072473',
#  'n00072691',
#  'n00072808',
#  'n00073032',
#  'n00073177',
#  'n00073713',
#  'n00073828',
#  'n00074324',
#  'n00074524',
#  'n00074624',
#  'n00074790',
#  'n00075283',
#  'n00075471',
#  'n00075790',
#  'n00075912',
#  'n00076072',
#  'n00076323',
#  'n00076393',
#  'n00076563',
#  'n00076884',
#  'n00077169',
#  'n00077249',
#  'n00077419',
#  'n00077856',
#  'n00077981',
#  'n00078217',
#  'n00078393',
#  'n00078536',
#  'n00079018',
#  'n00079212',
#  'n00079398',
#  'n00081174',
#  'n00081572',
#  'n00081836',
#  'n00082081',
#  'n00082525',
#  'n00082754',
#  'n00082870',
#  'n00083260',
#  'n00083448',
#  'n00083585',
#  'n00083729',
#  'n00083975',
#  'n00084371',
#  'n00084642',
#  'n00084895',
#  'n00085041',
#  'n00085219',
#  'n00085432',
#  'n00085678',
#  'n00085829',
#  'n00086140',
#  'n00086297',
#  'n00086654',
#  'n00086809',
#  'n00087218',
#  'n00087423',
#  'n00087663',
#  'n00087849',
#  'n00088481',
#  'n00088725',
#  'n00089027',
#  'n00089234',
#  'n00089351',
#  'n00089657',
#  'n00089891',
#  'n00090076',
#  'n00090253',
#  'n00090393',
#  'n00090779',
#  'n00091013',
#  'n00091234',
#  'n00091404',
#  'n00091503',
#  'n00091779',
#  'n00092366',
#  'n00092663',
#  'n00092847',
#  'n00093006',
#  'n00093127',
#  'n00093354',
#  'n00093483',
#  'n00093874',
#  'n00094001',
#  'n00094240',
#  'n00094500',
#  'n00094788',
#  'n00094954',
#  'n00095121',
#  'n00095329',
#  'n00095502',
#  'n00095971',
#  'n00096211',
#  'n00096343',
#  'n00096513',
#  'n00096851',
#  'n00096969',
#  'n00097122',
#  'n00097244',
#  'n00097348',
#  'n00097504',
#  'n00098385',
#  'n00098625',
#  'n00099439',
#  'n00099799',
#  'n00100543',
#  'n00100889',
#  'n00101003',
#  'n00101191',
#  'n00101410',
#  'n00101570',
#  'n00101708',
#  'n00101809',
#  'n00102162',
#  'n00102457',
#  'n00102779',
#  'n00102927',
#  'n00103140',
#  'n00103291',
#  'n00103590',
#  'n00103834',
#  'n00104088',
#  'n00104249',
#  'n00104409',
#  'n00104539',
#  'n00104976',
#  'n00105164',
#  'n00105271',
#  'n00105479',
#  'n00105624',
#  'n00105820',
#  'n00106104',
#  'n00106272',
#  'n00106726',
#  'n00106888',
#  'n00107016',
#  'n00107279',
#  'n00107400',
#  'n00107551',
#  'n00107875',
#  'n00108081',
#  'n00108181',
#  'n00108427',
#  'n00108818',
#  'n00108965',
#  'n00109081',
#  'n00109227',
#  'n00109414',
#  'n00110554',
#  'n00111503',
#  'n00112312',
#  'n00112674',
#  'n00112828',
#  'n00112997',
#  'n00113113',
#  'n00113532',
#  'n00113726',
#  'n00113954',
#  'n00114095',
#  'n00114298',
#  'n00114431',
#  'n00114871',
#  'n00115036',
#  'n00115292',
#  'n00115500',
#  'n00115667',
#  'n00115803',
#  'n00116008',
#  'n00116122',
#  'n00116376',
#  'n00116687',
#  'n00116989',
#  'n00117267',
#  'n00117578',
#  'n00117810',
#  'n00117959',
#  'n00118268',
#  'n00118552',
#  'n00118733',
#  'n00119079',
#  'n00119210',
#  'n00119297',
#  'n00119568',
#  'n00119893',
#  'n00120010',
#  'n00120202',
#  'n00120515',
#  'n00120804',
#  'n00120943',
#  'n00121166',
#  'n00121366',
#  'n00121645',
#  'n00121904',
#  'n00122106',
#  'n00122338',
#  'n00122530',
#  'n00122661',
#  'n00122954',
#  'n00123234',
#  'n00123430',
#  'n00123783',
#  'n00124008',
#  'n00124151',
#  'n00124256',
#  'n00124342',
#  'n00124536',
#  'n00124617',
#  'n00124766',
#  'n00124880',
#  'n00125126',
#  'n00125315',
#  'n00125436',
#  'n00125629',
#  'n00126100',
#  'n00126236',
#  'n00126447',
#  'n00126584',
#  'n00126721',
#  'n00126886',
#  'n00127021',
#  'n00127151',
#  'n00127531',
#  'n00127672',
#  'n00128324',
#  'n00128477',
#  'n00128638',
#  'n00128867',
#  'n00129089',
#  'n00129317',
#  'n00129435',
#  'n00129527',
#  'n00130093',
#  'n00130347',
#  'n00130512',
#  'n00130846',
#  'n00131485',
#  'n00131608',
#  'n00131791',
#  'n00132219',
#  'n00132355',
#  'n00132601',
#  'n00132756',
#  'n00132982',
#  'n00133160',
#  'n00133234',
#  'n00133338',
#  'n00133567',
#  'n00133668',
#  'n00133875',
#  'n00133981',
#  'n00134099',
#  'n00134391',
#  'n00134472',
#  'n00134574',
#  'n00134780',
#  'n00135148',
#  'n00135311',
#  'n00135504',
#  'n00135637',
#  'n00135799',
#  'n00135952',
#  'n00136230',
#  'n00136329',
#  'n00136984',
#  'n00137877',
#  'n00138078',
#  'n00138221',
#  'n00138599',
#  'n00138734',
#  'n00138956',
#  'n00139758',
#  'n00139919',
#  'n00140112',
#  'n00140393',
#  'n00140652',
#  'n00140900',
#  'n00141027',
#  'n00141176',
#  'n00141396',
#  'n00141806',
#  'n00142361',
#  'n00142665',
#  'n00143763',
#  'n00143885',
#  'n00144445',
#  'n00144632',
#  'n00144778',
#  'n00145024',
#  'n00145218',
#  'n00145779',
#  'n00145929',
#  'n00146111',
#  'n00146277',
#  'n00146443',
#  'n00146572',
#  'n00146856',
#  'n00147091',
#  'n00147187',
#  'n00147314',
#  'n00147454',
#  'n00147595',
#  'n00147862',
#  'n00148057',
#  'n00148242',
#  'n00148653',
#  'n00148836',
#  'n00148978',
#  'n00149084',
#  'n00149262',
#  'n00149508',
#  'n00150097',
#  'n00150591',
#  'n00150762',
#  'n00150932',
#  'n00151087',
#  'n00151409',
#  'n00151497',
#  'n00151914',
#  'n00152018',
#  'n00152338',
#  'n00152727',
#  'n00153665',
#  'n00153809',
#  'n00153961',
#  'n00154233',
#  'n00154433',
#  'n00154689',
#  'n00154894',
#  'n00155085',
#  'n00155298',
#  'n00155487',
#  'n00155797',
#  'n00155970',
#  'n00156119',
#  'n00156293',
#  'n00156390',
#  'n00156812',
#  'n00157081',
#  'n00157463',
#  'n00157687',
#  'n00157877',
#  'n00157957',
#  'n00158185',
#  'n00158805',
#  'n00158996',
#  'n00159177',
#  'n00159396',
#  'n00159620',
#  'n00159899',
#  'n00160073',
#  'n00160415',
#  'n00160532',
#  'n00160922',
#  'n00161044',
#  'n00161243',
#  'n00161603',
#  'n00161739',
#  'n00161888',
#  'n00162632',
#  'n00163047',
#  'n00163233',
#  'n00163630',
#  'n00163779',
#  'n00164152',
#  'n00164345',
#  'n00164579',
#  'n00164801',
#  'n00165178',
#  'n00165298',
#  'n00165563',
#  'n00165942',
#  'n00166172',
#  'n00166552',
#  'n00166702',
#  'n00167063',
#  'n00167278',
#  'n00167446',
#  'n00167764',
#  'n00167950',
#  'n00168121',
#  'n00168237',
#  'n00168505',
#  'n00168658',
#  'n00168911',
#  'n00169047',
#  'n00169147',
#  'n00169305',
#  'n00169651',
#  'n00169811',
#  'n00170340',
#  'n00170710',
#  'n00171249',
#  'n00171507',
#  'n00171618',
#  'n00172073',
#  'n00172217',
#  'n00172347',
#  'n00172490',
#  'n00172598',
#  'n00172710',
#  'n00173172',
#  'n00173283',
#  'n00173761',
#  'n00174003',
#  'n00174412',
#  'n00174663',
#  'n00176052',
#  'n00177448',
#  'n00177638',
#  'n00178551',
#  'n00178700',
#  'n00178832',
#  'n00179380',
#  'n00179576',
#  'n00179683',
#  'n00179916',
#  'n00180228',
#  'n00180413',
#  'n00180770',
#  'n00180962',
#  'n00181373',
#  'n00181495',
#  'n00181640',
#  'n00181781',
#  'n00182213',
#  'n00182571',
#  'n00183357',
#  'n00183505',
#  'n00185104',
#  'n00185307',
#  'n00186549',
#  'n00186634',
#  'n00187337',
#  'n00187710',
#  'n00187890',
#  'n00188183',
#  'n00188449',
#  'n00188620',
#  'n00188766',
#  'n00189106',
#  'n00189565',
#  'n00190431',
#  'n00190783',
#  'n00191142',
#  'n00191980',
#  'n00192149',
#  'n00192300',
#  'n00192457',
#  'n00192613',
#  'n00192910',
#  'n00193225',
#  'n00193406',
#  'n00194127',
#  'n00194257',
#  'n00194414',
#  'n00194645',
#  'n00194831',
#  'n00194969',
#  'n00195194',
#  'n00195415',
#  'n00195569',
#  'n00195938',
#  'n00196084',
#  'n00196402',
#  'n00196485',
#  'n00196848',
#  'n00197229',
#  'n00197610',
#  'n00197772',
#  'n00198118',
#  'n00198270',
#  'n00198451',
#  'n00198631',
#  'n00198793',
#  'n00198919',
#  'n00199707',
#  'n00200041',
#  'n00200244',
#  'n00200379',
#  'n00200563',
#  'n00200768',
#  'n00201058',
#  'n00201269',
#  'n00201397',
#  'n00201516',
#  'n00201671',
#  'n00201923',
#  'n00202284',
#  'n00202620',
#  'n00202816',
#  'n00203020',
#  'n00203342',
#  'n00203753',
#  'n00204022',
#  'n00204199',
#  'n00204439',
#  'n00204659',
#  'n00204814',
#  'n00204943',
#  'n00205079',
#  'n00205543',
#  'n00205649',
#  'n00205891',
#  'n00206130',
#  'n00206302',
#  'n00206779',
#  'n00206927',
#  'n00207306',
#  'n00207434',
#  'n00207622',
#  'n00207761',
#  'n00208277',
#  'n00208521',
#  'n00208694',
#  'n00208797',
#  'n00208943',
#  'n00209132',
#  'n00209301',
#  'n00209446',
#  'n00209546',
#  'n00209943',
#  'n00210518',
#  'n00210797',
#  'n00210940',
#  'n00211110',
#  'n00211462',
#  'n00212065',
#  'n00212205',
#  'n00212377',
#  'n00212551',
#  'n00212808',
#  'n00213052',
#  'n00213186',
#  'n00213343',
#  'n00213482',
#  'n00213694',
#  'n00213903',
#  'n00214148',
#  'n00215314',
#  'n00215534',
#  'n00215683',
#  'n00215838',
#  'n00216038',
#  'n00216174',
#  'n00216607',
#  'n00216723',
#  'n00216834',
#  'n00217014',
#  'n00217499',
#  'n00217593',
#  'n00218045',
#  'n00218208',
#  'n00218427',
#  'n00218602',
#  'n00218753',
#  'n00218902',
#  'n00219012',
#  'n00219463',
#  'n00219575',
#  'n00219856',
#  'n00220023',
#  'n00220409',
#  'n00220522',
#  'n00221056',
#  'n00221178',
#  'n00221596',
#  'n00221727',
#  'n00221819',
#  'n00221900',
#  'n00221981',
#  'n00222064',
#  'n00222155',
#  'n00222248',
#  'n00222376',
#  'n00222485',
#  'n00223362',
#  'n00223575',
#  'n00223720',
#  'n00223854',
#  'n00223983',
#  'n00224260',
#  'n00224599',
#  'n00224738',
#  'n00224936',
#  'n00225070',
#  'n00225150',
#  'n00225593',
#  'n00225786',
#  'n00226107',
#  'n00226319',
#  'n00226511',
#  'n00226951',
#  'n00227264',
#  'n00227484',
#  'n00227595',
#  'n00227848',
#  'n00227969',
#  'n00228078',
#  'n00228181',
#  'n00228283',
#  'n00228535',
#  'n00228911',
#  'n00229260',
#  'n00229814',
#  'n00229934',
#  'n00230172',
#  'n00230324',
#  'n00231567',
#  'n00231887',
#  'n00232147',
#  'n00232386',
#  'n00232765',
#  'n00233386',
#  'n00233614',
#  'n00233795',
#  'n00234423',
#  'n00234675',
#  'n00234892',
#  'n00235074',
#  'n00235208',
#  'n00235435',
#  'n00236194',
#  'n00236581',
#  'n00236821',
#  'n00236953',
#  'n00237078',
#  'n00237869',
#  'n00238022',
#  'n00238527',
#  'n00239483',
#  'n00239766',
#  'n00239910',
#  'n00240184',
#  'n00240754',
#  'n00240938',
#  'n00241507',
#  'n00241699',
#  'n00242003',
#  'n00242146',
#  'n00242431',
#  'n00242583',
#  'n00242808',
#  'n00243102',
#  'n00243373',
#  'n00243918',
#  'n00246341',
#  'n00246460',
#  'n00246552',
#  'n00246754',
#  'n00246940',
#  'n00247229',
#  'n00247342',
#  'n00247442',
#  'n00247654',
#  'n00247792',
#  'n00247955',
#  'n00248252',
#  'n00248368',
#  'n00248534',
#  'n00248636',
#  'n00248748',
#  'n00248977',
#  'n00249501',
#  'n00249780',
#  'n00249987',
#  'n00250259',
#  'n00250597',
#  'n00250710',
#  'n00251013',
#  'n00251520',
#  'n00251780',
#  'n00252020',
#  'n00252307',
#  'n00252430',
#  'n00252662',
#  'n00252894',
#  'n00253070',
#  'n00253270',
#  'n00253395',
#  'n00253577',
#  'n00253919',
#  'n00254166',
#  'n00254415',
#  'n00254597',
#  'n00254769',
#  'n00254922',
#  'n00255065',
#  'n00255450',
#  'n00255600',
#  'n00255710',
#  'n00256309',
#  'n00256407',
#  'n00256501',
#  'n00256620',
#  'n00256746',
#  'n00257115',
#  'n00257580',
#  'n00257770',
#  'n00258093',
#  'n00258695',
#  'n00258854',
#  'n00259177',
#  'n00259392',
#  'n00259544',
#  'n00259643',
#  'n00259894',
#  'n00260051',
#  'n00260494',
#  'n00260622',
#  'n00261029',
#  'n00261405',
#  'n00261604',
#  'n00261972',
#  'n00262249',
#  'n00262596',
#  'n00262743',
#  'n00263000',
#  'n00263164',
#  'n00263272',
#  'n00263353',
#  'n00263642',
#  'n00263813',
#  'n00263947',
#  'n00264088',
#  'n00264192',
#  'n00264366',
#  'n00264529',
#  'n00264775',
#  'n00264913',
#  'n00265119',
#  'n00265773',
#  'n00265992',
#  'n00266149',
#  'n00266253',
#  'n00266401',
#  'n00266645',
#  'n00266806',
#  'n00267217',
#  'n00267349',
#  'n00267522',
#  'n00268112',
#  'n00268557',
#  'n00268824',
#  'n00269018',
#  'n00269258',
#  'n00269471',
#  'n00269674',
#  'n00269856',
#  'n00270186',
#  'n00270275',
#  'n00270800',
#  'n00270919',
#  'n00271155',
#  'n00271263',
#  'n00271636',
#  'n00271879',
#  'n00272123',
#  'n00272303',
#  'n00272448',
#  'n00272713',
#  'n00273077',
#  'n00273319',
#  'n00273449',
#  'n00273601',
#  'n00273877',
#  'n00274009',
#  'n00274206',
#  'n00274437',
#  'n00274586',
#  'n00274707',
#  'n00274941',
#  'n00275151',
#  'n00275424',
#  'n00275572',
#  'n00276189',
#  'n00276342',
#  'n00276620',
#  'n00276813',
#  'n00276987',
#  'n00277376',
#  'n00277569',
#  'n00277811',
#  'n00278040',
#  'n00278221',
#  'n00278403',
#  'n00278555',
#  'n00278810',
#  'n00279136',
#  'n00279235',
#  'n00279377',
#  'n00279534',
#  'n00279674',
#  'n00279835',
#  'n00280586',
#  'n00280853',
#  'n00281132',
#  'n00281462',
#  'n00281898',
#  'n00282050',
#  'n00282485',
#  'n00282613',
#  'n00282840',
#  'n00283127',
#  'n00283450',
#  'n00283568',
#  'n00283951',
#  'n00284101',
#  ...)

# %% [markdown]
# ### Search text -> image
# **Let's try to take a word from WordNet, get the wordvector from FastText. We then make an nearest neighbour index of all the predicted wordvecs of the validation dataset and find the nearest neighbours in this validation dataset to the word from WordNet:**

# %% [markdown]
# An index of all the **predicted** word vectors of the validation dataset:

# %%
predicted_word_vectors_index = create_index(predicted_word_vecs)

# %%
vec = wordvector_dict["boat"]

# %%
indcs, dists = get_knn(predicted_word_vectors_index, vec)

# %%
show_imgs([open_image(PATH/modeldata.val_ds.fnames[i]) for i in indcs[:3]], 3, figsize=(9,3));

# %% [markdown]
# **That looks like boats to me :) And the incredible thing is that 'boat' is not even an imagenet category. So the pretrained network has never classified these images as boats.**
#
# **Can we also find results in the validation dataset (the wordvectors are predicted) by interpolating between the wordvectors of two words from WordNet (word vectors from FastText)??**

# %%
vec = (wordvector_dict['engine'] + wordvector_dict['boat'])/2

# %%
indcs, dists = get_knn(predicted_word_vectors_index, vec)
show_imgs([open_image(PATH/modeldata.val_ds.fnames[i]) for i in indcs[:3]], 3, figsize=(9,3));

# %%
vec = (wordvector_dict['sail'] + wordvector_dict['boat'])/2

# %%
indcs, dists = get_knn(predicted_word_vectors_index, vec)
show_imgs([open_image(PATH/modeldata.val_ds.fnames[i]) for i in indcs[:3]], 3, figsize=(9,3));

# %% [markdown]
# **Wow, this actually works :) and neighter 'sail' or 'boat' are imagenet classes**

# %% [markdown]
# ### Search image -> image
# Take an image, predict the word vector and than find word vectors that are similar to this one:

# %%
fname = 'data/imagenet/train/n02091467/n02091467_1927.JPEG'

# %%
img = open_image(fname)

# %%
show_img(img)

# %%
transformed_img = modeldata.val_ds.transform(img)

# %%
transformed_img[None][0].shape
# Out:
# (3, 224, 224)

# %%
show_img(transformed_img[None][0].transpose(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
learn.precompute = False

# %%
pred = learn.predict_array(transformed_img[None])

# %%
indcs, dists = get_knn(predicted_word_vectors_index, pred)
show_imgs([open_image(PATH/modeldata.val_ds.fnames[i]) for i in indcs[:3]], 3, figsize=(9,3));

# %% [markdown]
# **And these are dogs too :)**

# %% [markdown]
# ## Summary
# **We used three different kinds of searches now:**
#
# 1. Calculate the nearest neighbour index for all imagenet or wordnet class wordvecs (taken from FastText). Predict the wordvec for an image in the validation dataset. Find the nearest neighbours of this wordvec. This gives you class names from imagenet or wordnet for the specified image.
# 1. Calculate the nearest neighbour index of all the predicted wordvecs of the validation dataset and then find the nearest neighbours of a wordvec belonging to a word from WordNet (or an interpolation of wordvecs of words belonging to wordnet). You specify a string and get an image.
# 1.  Calculate the nearest neighbour index of all the predicted wordvecs of the validation dataset. Predict a wordvec for an image and then find other images from the validation dataset that have similar predicted wordvecs.

# %% [markdown]
# # Preparing for deoplying with docker

# %% [markdown]
# ### Saving classifier and wordvectors

# %%
import dill as dill

# %%
DEPL_PATH = Path('deployment/devise/')

# %%
torch.save(learn.model, DEPL_PATH/'model2.pth')

# %%
model = torch.load(DEPL_PATH/'model2.pth')

# %%
classId2wordvec = [[classIds_wordnet[id], vec] for id, vec in wordnet_id2wordvec]

# %%
pickle.dump(classId2wordvec, (DEPL_PATH/'classId2wordvec.pkl').open('wb'))

# %% [markdown]
# ### Saving validation images

# %%
valid_images = np.array(input_images)[val_indcs]+

# %%
len(valid_images)
# Out:
# 1404

# %%
os.mkdir(PATH/'valid')

# %%
for file in valid_images:
    src = file
    dst = file.replace('train', 'valid')
    dstfolder = PATH/os.path.dirname(dst)
    if not os.path.exists(dstfolder):
        os.mkdir(dstfolder)
    shutil.copy(PATH/src, PATH/dst)
